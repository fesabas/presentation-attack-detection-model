# %%
import cv2
import tensorflow as tf
import numpy as np
from PIL import Image
from keras.models import load_model
from tensorflow.keras.optimizers.legacy import Adam
from tensorflow.keras.applications.resnet50 import preprocess_input
# from keras.application.inception_v3 import preprocess_input

# %%
model = load_model("./model/color_detection_adam_0.0000001.h5", compile = False)

# %%
x = tf.io.read_file('/Users/location')
x = tf.io.decode_image(x,channels=3)
x = tf.expand_dims(x, axis=0)
x = preporcess_input(x)
x.shape

# %%
predictions = model,predict(x)

# %%
predictions

# %%
print (predictions.argmax(axis=1))

# %%
interpreter = tf.lite.Interpreter(model_path='./model/screen_detection.tflite')
interpereter.allocate_tensors()

#Get input and putput details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input-details[0]['index'], x)
interpreter.invoke()
predictions = interpreter.get_tensor(output_details[0]['index'])
print("Predicted:", predictions)

# %%
type(predictions)

# %%
predictions[0]

# %% [markdown]
# GRAD-CAM Interpretation

# %%
with tf.GradientTape() as tape:
    last_conv_layer = model.get_layer('conv2d_93') #Replace with the acutal name of your last convolutional layer
    iterate = tf.keras.models.Model([model.inputs], [model.output, last_conv_layer.output])
    model_out, last_conv_layer = iterate(x)
    class_out = model_out[:, np.argmax(model_out[0])]
grads = tape.gradient(class_out, last_conv_layer)
pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
